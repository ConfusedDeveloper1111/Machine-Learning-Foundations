# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from statsmodels.tsa.stattools import adfuller

# %%
df = pd.read_csv(r"D:\TS dataset\shampoo_trend.csv")

# %%
df
# Out:
#      Month  Sales
# 0    1-Jan  266.0
# 1    2-Jan  145.9
# 2    3-Jan  183.1
# 3    4-Jan  119.3
# 4    5-Jan  180.3
# 5    6-Jan  168.5
# 6    7-Jan  231.8
# 7    8-Jan  224.5
# 8    9-Jan  192.8
# 9   10-Jan  122.9
# 10  11-Jan  336.5
# 11  12-Jan  185.9
# 12   1-Feb  194.3
# 13   2-Feb  149.5
# 14   3-Feb  210.1
# 15   4-Feb  273.3
# 16   5-Feb  191.4
# 17   6-Feb  287.0
# 18   7-Feb  226.0
# 19   8-Feb  303.6
# 20   9-Feb  289.9
# 21  10-Feb  421.6
# 22  11-Feb  264.5
# 23  12-Feb  342.3
# 24   1-Mar  339.7
# 25   2-Mar  440.4
# 26   3-Mar  315.9
# 27   4-Mar  439.3
# 28   5-Mar  401.3
# 29   6-Mar  437.4
# 30   7-Mar  575.5
# 31   8-Mar  407.6
# 32   9-Mar  682.0
# 33  10-Mar  475.3
# 34  11-Mar  581.3
# 35  12-Mar  646.9

# %%
date = ["01-Feb-2026", "02-Feb-2026", "03-Feb-2026", "04-Feb-2026", "05-Feb-2026", "06-Feb-2026"]

# %%
date
# Out:
# ['01-Feb-2026',
#  '02-Feb-2026',
#  '03-Feb-2026',
#  '04-Feb-2026',
#  '05-Feb-2026',
#  '06-Feb-2026']

# %%
df1 = pd.DataFrame(date, columns = ["Date"])

# %%
df1
# Out:
#           Date
# 0  01-Feb-2026
# 1  02-Feb-2026
# 2  03-Feb-2026
# 3  04-Feb-2026
# 4  05-Feb-2026
# 5  06-Feb-2026

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type( df1["Date"] )
# Out:
# pandas.core.series.Series

# %%
df1["Date"].dtype
# Out:
# dtype('O')

# %%
pd.to_datetime(df1["Date"])
# Out:
# 0   2026-02-01
# 1   2026-02-02
# 2   2026-02-03
# 3   2026-02-04
# 4   2026-02-05
# 5   2026-02-06
# Name: Date, dtype: datetime64[ns]

# %%
df1 = pd.to_datetime(df1["Date"])

# %%
df1
# Out:
# 0   2026-02-01
# 1   2026-02-02
# 2   2026-02-03
# 3   2026-02-04
# 4   2026-02-05
# 5   2026-02-06
# Name: Date, dtype: datetime64[ns]

# %%
df1 = pd.DataFrame(df1, columns = ["Date"])

# %%
df1
# Out:
#         Date
# 0 2026-02-01
# 1 2026-02-02
# 2 2026-02-03
# 3 2026-02-04
# 4 2026-02-05
# 5 2026-02-06

# %%
df1["Date"].dt.year
# Out:
# 0    2026
# 1    2026
# 2    2026
# 3    2026
# 4    2026
# 5    2026
# Name: Date, dtype: int32

# %%
df1["Date"].dt.day_name()
# Out:
# 0       Sunday
# 1       Monday
# 2      Tuesday
# 3    Wednesday
# 4     Thursday
# 5       Friday
# Name: Date, dtype: object

# %%
df
# Out:
#      Month  Sales
# 0    1-Jan  266.0
# 1    2-Jan  145.9
# 2    3-Jan  183.1
# 3    4-Jan  119.3
# 4    5-Jan  180.3
# 5    6-Jan  168.5
# 6    7-Jan  231.8
# 7    8-Jan  224.5
# 8    9-Jan  192.8
# 9   10-Jan  122.9
# 10  11-Jan  336.5
# 11  12-Jan  185.9
# 12   1-Feb  194.3
# 13   2-Feb  149.5
# 14   3-Feb  210.1
# 15   4-Feb  273.3
# 16   5-Feb  191.4
# 17   6-Feb  287.0
# 18   7-Feb  226.0
# 19   8-Feb  303.6
# 20   9-Feb  289.9
# 21  10-Feb  421.6
# 22  11-Feb  264.5
# 23  12-Feb  342.3
# 24   1-Mar  339.7
# 25   2-Mar  440.4
# 26   3-Mar  315.9
# 27   4-Mar  439.3
# 28   5-Mar  401.3
# 29   6-Mar  437.4
# 30   7-Mar  575.5
# 31   8-Mar  407.6
# 32   9-Mar  682.0
# 33  10-Mar  475.3
# 34  11-Mar  581.3
# 35  12-Mar  646.9

# %%
df.columns
# Out:
# Index(['Month', 'Sales'], dtype='object')

# %%
df["Month"]
# Out:
# 0      1-Jan
# 1      2-Jan
# 2      3-Jan
# 3      4-Jan
# 4      5-Jan
# 5      6-Jan
# 6      7-Jan
# 7      8-Jan
# 8      9-Jan
# 9     10-Jan
# 10    11-Jan
# 11    12-Jan
# 12     1-Feb
# 13     2-Feb
# 14     3-Feb
# 15     4-Feb
# 16     5-Feb
# 17     6-Feb
# 18     7-Feb
# 19     8-Feb
# 20     9-Feb
# 21    10-Feb
# 22    11-Feb
# 23    12-Feb
# 24     1-Mar
# 25     2-Mar
# 26     3-Mar
# 27     4-Mar
# 28     5-Mar
# 29     6-Mar
# 30     7-Mar
# 31     8-Mar
# 32     9-Mar
# 33    10-Mar
# 34    11-Mar
# 35    12-Mar
# Name: Month, dtype: object

# %%
pd.to_datetime(df["Month"])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19396\1944986573.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df["Month"])
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File conversion.pyx:326, in pandas._libs.tslibs.conversion._TSObject.ensure_reso()
#
# File np_datetime.pyx:683, in pandas._libs.tslibs.np_datetime.convert_reso()
#
# OverflowError: result would overflow
#
# The above exception was the direct cause of the following exception:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 pd.to_datetime(df["Month"])
#
# ...

# %%
pd.to_datetime(df["Month"] + "-2026")
# Out:
# 0    2026-01-01
# 1    2026-01-02
# 2    2026-01-03
# 3    2026-01-04
# 4    2026-01-05
# 5    2026-01-06
# 6    2026-01-07
# 7    2026-01-08
# 8    2026-01-09
# 9    2026-01-10
# 10   2026-01-11
# 11   2026-01-12
# 12   2026-02-01
# 13   2026-02-02
# 14   2026-02-03
# 15   2026-02-04
# 16   2026-02-05
# 17   2026-02-06
# 18   2026-02-07
# 19   2026-02-08
# 20   2026-02-09
# 21   2026-02-10
# 22   2026-02-11
# 23   2026-02-12
# 24   2026-03-01
# 25   2026-03-02
# 26   2026-03-03
# 27   2026-03-04
# 28   2026-03-05
# 29   2026-03-06
# 30   2026-03-07
# 31   2026-03-08
# 32   2026-03-09
# 33   2026-03-10
# 34   2026-03-11
# 35   2026-03-12
# Name: Month, dtype: datetime64[ns]

# %%
df["Month"] + "-2026"
# Out:
# 0      1-Jan- 2026
# 1      2-Jan- 2026
# 2      3-Jan- 2026
# 3      4-Jan- 2026
# 4      5-Jan- 2026
# 5      6-Jan- 2026
# 6      7-Jan- 2026
# 7      8-Jan- 2026
# 8      9-Jan- 2026
# 9     10-Jan- 2026
# 10    11-Jan- 2026
# 11    12-Jan- 2026
# 12     1-Feb- 2026
# 13     2-Feb- 2026
# 14     3-Feb- 2026
# %%
df.set_index("Date", inplace = True)

# %%
df
# Out:
#             Sales
# Date
# 2026-01-01  266.0
# 2026-01-02  145.9
# 2026-01-03  183.1
# 2026-01-04  119.3
# 2026-01-05  180.3
# 2026-01-06  168.5
# 2026-01-07  231.8
# 2026-01-08  224.5
# 2026-01-09  192.8
# 2026-01-10  122.9
# 2026-01-11  336.5
# 2026-01-12  185.9
# 2026-02-01  194.3
# 2026-02-02  149.5
# 2026-02-03  210.1
# 2026-02-04  273.3
# 2026-02-05  191.4
# 2026-02-06  287.0
# 2026-02-07  226.0
# 2026-02-08  303.6
# 2026-02-09  289.9
# 2026-02-10  421.6
# 2026-02-11  264.5
# 2026-02-12  342.3
# 2026-03-01  339.7
# 2026-03-02  440.4
# 2026-03-03  315.9
# 2026-03-04  439.3
# 2026-03-05  401.3
# 2026-03-06  437.4
# 2026-03-07  575.5
# 2026-03-08  407.6
# 2026-03-09  682.0
# 2026-03-10  475.3
# 2026-03-11  581.3
# 2026-03-12  646.9

# %%
df["Sales"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
np.sort(df["Sales"])
# Out:
# array([119.3, 122.9, 145.9, 149.5, 168.5, 180.3, 183.1, 185.9, 191.4,
#        192.8, 194.3, 210.1, 224.5, 226. , 231.8, 264.5, 266. , 273.3,
#        287. , 289.9, 303.6, 315.9, 336.5, 339.7, 342.3, 401.3, 407.6,
#        421.6, 437.4, 439.3, 440.4, 475.3, 575.5, 581.3, 646.9, 682. ])

# %%
plt.plot(np.sort(df["Sales"]))

# %%
dfnew = pd.read_csv(r"D:\TS dataset\shampoo_trend.csv")

# %%
dfnew
# Out:
#      Month  Sales
# 0    1-Jan  266.0
# 1    2-Jan  145.9
# 2    3-Jan  183.1
# 3    4-Jan  119.3
# 4    5-Jan  180.3
# 5    6-Jan  168.5
# 6    7-Jan  231.8
# 7    8-Jan  224.5
# 8    9-Jan  192.8
# 9   10-Jan  122.9
# 10  11-Jan  336.5
# 11  12-Jan  185.9
# 12   1-Feb  194.3
# 13   2-Feb  149.5
# 14   3-Feb  210.1
# 15   4-Feb  273.3
# 16   5-Feb  191.4
# 17   6-Feb  287.0
# 18   7-Feb  226.0
# 19   8-Feb  303.6
# 20   9-Feb  289.9
# 21  10-Feb  421.6
# 22  11-Feb  264.5
# 23  12-Feb  342.3
# 24   1-Mar  339.7
# 25   2-Mar  440.4
# 26   3-Mar  315.9
# 27   4-Mar  439.3
# 28   5-Mar  401.3
# 29   6-Mar  437.4
# 30   7-Mar  575.5
# 31   8-Mar  407.6
# 32   9-Mar  682.0
# 33  10-Mar  475.3
# 34  11-Mar  581.3
# 35  12-Mar  646.9

# %%
dfnew["Sales"].plot()
# Out:
# <Axes: >

# %%
df["Sales"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adf1 = adfuller(df["Sales"])

# %%
adf1
# Out:
# (np.float64(3.060142083641183),
#  1.0,
#  10,
#  25,
#  {'1%': np.float64(-3.7238633119999998),
#   '5%': np.float64(-2.98648896),
#   '10%': np.float64(-2.6328004)},
#  np.float64(278.9972644263031))

# %%
dfnew["Sales"].plot()
# Out:
# <Axes: >

# %%
adf2 = adfuller(dfnew["Sales"])

# %%
adf2
# Out:
# (np.float64(3.060142083641183),
#  1.0,
#  10,
#  25,
#  {'1%': np.float64(-3.7238633119999998),
#   '5%': np.float64(-2.98648896),
#   '10%': np.float64(-2.6328004)},
#  np.float64(278.9972644263031))

# %% [markdown]
# ### Removing Trend

# %%
df["Sales"]
# Out:
# Date
# 2026-01-01    266.0
# 2026-01-02    145.9
# 2026-01-03    183.1
# 2026-01-04    119.3
# 2026-01-05    180.3
# 2026-01-06    168.5
# 2026-01-07    231.8
# 2026-01-08    224.5
# 2026-01-09    192.8
# 2026-01-10    122.9
# 2026-01-11    336.5
# 2026-01-12    185.9
# 2026-02-01    194.3
# 2026-02-02    149.5
# 2026-02-03    210.1
# 2026-02-04    273.3
# 2026-02-05    191.4
# 2026-02-06    287.0
# 2026-02-07    226.0
# 2026-02-08    303.6
# 2026-02-09    289.9
# 2026-02-10    421.6
# 2026-02-11    264.5
# 2026-02-12    342.3
# 2026-03-01    339.7
# 2026-03-02    440.4
# 2026-03-03    315.9
# 2026-03-04    439.3
# 2026-03-05    401.3
# 2026-03-06    437.4
# 2026-03-07    575.5
# 2026-03-08    407.6
# 2026-03-09    682.0
# 2026-03-10    475.3
# 2026-03-11    581.3
# 2026-03-12    646.9
# Name: Sales, dtype: float64

# %%
diff_sales = np.diff(df["Sales"], n=1)

# %%
diff_sales
# Out:
# array([-120.1,   37.2,  -63.8,   61. ,  -11.8,   63.3,   -7.3,  -31.7,
#         -69.9,  213.6, -150.6,    8.4,  -44.8,   60.6,   63.2,  -81.9,
#          95.6,  -61. ,   77.6,  -13.7,  131.7, -157.1,   77.8,   -2.6,
#         100.7, -124.5,  123.4,  -38. ,   36.1,  138.1, -167.9,  274.4,
#        -206.7,  106. ,   65.6])

# %%
plt.plot(diff_sales)

# %%
adf_3 = adfuller(diff_sales)

# %%
adf_3
# Out:
# (np.float64(-7.249074055553852),
#  np.float64(1.799857414168716e-10),
#  1,
#  33,
#  {'1%': np.float64(-3.6461350877925254),
#   '5%': np.float64(-2.954126991123355),
#   '10%': np.float64(-2.6159676124885216)},
#  np.float64(275.32503579406307))

# %%
dfnew["Sales"].plot()
# Out:
# <Axes: >

# %%
diff_sales_new = np.diff(dfnew["Sales"], n = 1)

# %%
diff_sales_new
# Out:
# array([-120.1,   37.2,  -63.8,   61. ,  -11.8,   63.3,   -7.3,  -31.7,
#         -69.9,  213.6, -150.6,    8.4,  -44.8,   60.6,   63.2,  -81.9,
#          95.6,  -61. ,   77.6,  -13.7,  131.7, -157.1,   77.8,   -2.6,
#         100.7, -124.5,  123.4,  -38. ,   36.1,  138.1, -167.9,  274.4,
#        -206.7,  106. ,   65.6])

# %%
plt.plot(diff_sales_new)

# %%
adf_4 = adfuller(diff_sales_new)

# %%
adf_4
# Out:
# (np.float64(-7.249074055553852),
#  np.float64(1.799857414168716e-10),
#  1,
#  33,
#  {'1%': np.float64(-3.6461350877925254),
#   '5%': np.float64(-2.954126991123355),
#   '10%': np.float64(-2.6159676124885216)},
#  np.float64(275.32503579406307))
